# %% [markdown]
# <div align="center">
#   <h1><b> Quantum Information </b></h1>
#   <h2> Entanglement </h2>
#   <h3> EPR Paradox </h3>
# </div>
#
# <br>
# <b>Author:</b> <a target="_blank" href="https://github.com/camponogaraviera">Lucas Camponogara Viera</a>

# %% [markdown]
# # Table of Contents
#
# - [EPR Hypothesis](#epr-hypothesis)
# - [EPR Argument](#epr-argument)

# %% [markdown]
# # EPR Hypothesis

# %% [markdown]
# In considering Max Born's probabilistic interpretation of the wave function, Albert Einstein addressed the mechanism of the wave function collapse during discussions at the 1927 Solvay conference. Einstein's gedanken (thought experiment) considered the diffraction of a beam of a single electron passing through a pinhole. According to the principle of superposition, before the electron hits a screen, the wave function in the position space represents the superposition of all the eigenstates associated with the positions available to the electron on that screen. The act of measurement would then cause the wave function to collapse to a single eingestate of the position observable. Einstein referred to this mechanism by which the wave function is instantly updated as action at a distance.
#
# Einstein went further with his hypothesis that quantum mechanics was incomplete and published, among three other physicists, the so-called EPR paper in 1935. The paper devised a thought experiment considering a system of two entangled particles to assess whether a measurement in one particle would have an instantaneous effect on the other. The starting point of the EPR paper adopts the following definitions regarding the quantum mechanical theory:
#
# - `Realism:` Every element of reality in nature (the so-called observables) must be predicted within the quantum theory without causing any disturbance to the quantum system. That is, it should be possible to predict the outcome of a measurement with 100\% certainty before the measurement is even realized.
#
# - `Self-consistency:` A quantum theory shall be able to predict and explain experimental data in a consistent manner, i.e., free of contradictions.
#
# - `Completeness:` A complete quantum theory is such that there is a theoretical analogue for every element of reality in nature.
#
# - `Locality:` A measurement in one subsystem should not influence the outcome of a measurement in another subsystem.

# %% [markdown]
# The EPR paper argue that:
#
# 1. If quantum mechanics were complete, then non-commuting (conjugate) observables $\hat{X}$ and $\hat{Z}$ (e.g. spin $\hat{\sigma}_x$ and $\hat{\sigma}_z$) could not have simultaneous elements of reality.
#
# 2. But the EPR reasoning shows that $\hat{X}$ and $\hat{Z}$ do have simultaneous elements of reality. Why?
#     - By measuring $\hat{X}$ on qubit 1, it is possible to predict with certainty the value of $\hat{X}$ for qubit 2 without disturbing qubit 2.
#     - By measuring $\hat{Z}$ on qubit 1, it is possible to predict with certainty the value of $\hat{Z}$ for qubit 2 without disturbing qubit 2.
#
# Therefore:
#
# 3. The theory of quantum mechanics should be incomplete. There should be a theory of hidden variables.

# %% [markdown]
# # EPR Argument

# %% [markdown]
# Consider a bipartite system (quantum state) of two spin 1/2.
#
# In the $Z$-basis $\{|0\rangle, |1\rangle\}$:
#
# \begin{align}
# |\psi^- \rangle &:= \frac{1}{\sqrt 2}(|01\rangle_{AB} - |10\rangle_{AB}) \\
# &= \frac{1}{\sqrt 2}(|0\rangle_A \otimes |1\rangle_B - |1\rangle_A \otimes |0\rangle_B)
# \end{align}
#
# In the $X$-basis $\{|+\rangle, |-\rangle\}$:
#
# $$|\psi^- \rangle := \frac{1}{\sqrt 2}(|+\rangle_A \otimes |-\rangle_B - |-\rangle_A \otimes |+\rangle_B).$$

# %% [markdown]
# Recall the measurement postulate:
#
# \begin{align}
# |\psi \rangle \rightarrow |\psi_{o_j} \rangle = \frac{\Pi_{o_j} |\psi \rangle}{\sqrt{\langle \psi | \Pi^{\dagger}_{o_j} \Pi_{o_j} |\psi \rangle}}
# = \frac{\Pi_{o_j} |\psi \rangle}{|| \Pi_{o_j} |\psi \rangle ||},
# \end{align}
#
# and the algebraic idendity $(A \otimes B)(C \otimes D) = (AC) \otimes (BD)$.

# %% [markdown]
# The state of the system immediately after measuring observable $\hat{Z}$ on Alice's qubit (subsystem A) to get the eigenvalue associated with eigenvector $|0\rangle_A$ is:
#
# \begin{align}
# \Pi_{|0\rangle}^A |\psi^- \rangle &= \big( _A|0\rangle \langle 0| \otimes \mathbb{I}_B \big) |\psi^- \rangle \\
# &= \frac{1}{\sqrt 2} \big( _A|0\rangle \langle 0| \otimes \mathbb{I}_B \big) \cdot (|0\rangle_A \otimes |1\rangle_B - |1\rangle_A \otimes |0\rangle_B)\\
# &= _A|0\rangle \langle 0| |0\rangle_A \otimes  \mathbb{I}_B |1\rangle_B - _A|0\rangle \langle 0||1\rangle_A \otimes \mathbb{I}_B |0\rangle_B \\
# &= \frac{1}{\sqrt 2} (|0\rangle_A \otimes |1\rangle_B).
# \end{align}
#
# \begin{align}
# \therefore \frac{\Pi_{|0\rangle}^A |\psi^- \rangle}{{|| \Pi_{|0\rangle} |\psi \rangle ||}} &= \frac{\frac{1}{\sqrt 2} (|0\rangle_A \otimes |1\rangle_B)}{\frac{1}{\sqrt 2}} = |0\rangle_A \otimes |1\rangle_B.
# \end{align}

# %% [markdown]
# The state of the system immediately after measuring observable $\hat{X}$ on Alice's qubit (subsystem A) to get the eigenvalue associated with eigenvector $|+\rangle_A$ is:
#
# \begin{align}
# \Pi_{|+\rangle}^A |\psi^- \rangle &= \big(|+\rangle \langle +|_A \otimes \mathbb{I}_B \big) |\psi^- \rangle \\
# &= \frac{1}{\sqrt 2} \big( _A|+\rangle \langle +| \otimes \mathbb{I}_B \big) \cdot (|+\rangle_{A} \otimes |-\rangle_B - |-\rangle_{A} \otimes |+\rangle_B) \\
# &= _A|+\rangle \langle +| |+\rangle_A \otimes  \mathbb{I}_B |+\rangle_B - _A|+\rangle \langle +||-\rangle_A \otimes \mathbb{I}_B |+\rangle_B \\
# &= \frac{1}{\sqrt 2} (|+\rangle_A \otimes |-\rangle_B).
# \end{align}
#
# \begin{align}
# \therefore \frac{\Pi_{|+\rangle}^A |\psi^- \rangle}{{|| \Pi_{{|+\rangle}} |\psi \rangle ||}} &= \frac{\frac{1}{\sqrt 2} (|+\rangle_A \otimes |-\rangle_B)}{\frac{1}{\sqrt 2}} = |+\rangle_A \otimes |-\rangle_B.
# \end{align}

# %% [markdown]
# This means that it is possible to predict the outcomes of two conjugate observables ($X$ and $Z$) on Bob's qubit without disturbing Bob's system due to the quantum correlatios between the two qubits.

# %% [markdown]
# # &nbsp; <a href="#"><img valign="middle" height="45px" src="https://img.icons8.com/book" width="45" hspace="0px" vspace="0px"></a> References<a name="ref" />

# %% [markdown]
# \[1] Nielsen MA, Chuang IL. 2010. Quantum Computation and Quantum Information. New York: [Cambridge Univ. Press.](https://doi.org/10.1017/CBO9780511976667) 10th Anniv. Ed.
#
# [4] Below videos from Sabine Hossenfelder's YouTube channel.
# - [Understanding Quantum Mechanics #1: It’s not about discreteness](https://www.youtube.com/watch?v=XJSfgE9LUJw)
# - [Understanding Quantum Mechanics #2: Superposition and Entanglement](https://www.youtube.com/watch?v=j6Mw3_tOcNI)
# - [Understanding Quantum Mechanics #3: Non-locality](https://www.youtube.com/watch?v=XL9wWeEmQvo)
# - [Understanding Quantum Mechanics #4: It's not so difficult!](https://www.youtube.com/watch?v=ctXDXABJRtg)
