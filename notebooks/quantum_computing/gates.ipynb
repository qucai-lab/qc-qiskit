# %% [markdown]
# <div align="center">
#   <h1><b> Quantum Computing </b></h1>
#   <h2> Quantum Gates </h2>
#   <h3> Introduction </h3>
# </div>
#
# <br>
# <b>Author:</b> <a target="_blank" href="https://github.com/camponogaraviera">Lucas Camponogara Viera</a>

# %% [markdown]
# # Table of Contents
#
# - [Introduction](#introduction)
# - [Examples](#examples)

# %% [markdown]
# # Introduction

# %% [markdown]
# A quantum gate is a linear operator (matrix) that evolves a quantum state $|\psi\rangle$ in a given basis. Given an arbitrary quantum state $|\psi\rangle$ and a gate $U$, the action of the gate upon such statevector is represented by:
#
# $$U|\psi\rangle,$$
#
# which is a product between the matrix representing the gate and the vector representing the quantum state.

# %% [markdown]
# When a given state $|\psi_j\rangle$ is said to be an eigenstate of the quantum gate (linear operator), this action is described by an eigenvalue-eigenvector equation:
#
# $$U |\psi_j\rangle = \lambda_j |\psi_j\rangle.$$

# %% [markdown]
# # Examples

# %% [markdown]
# Computational basis states:
#
# $$|0\rangle := \begin{bmatrix} 1 \\ 0 \end{bmatrix},$$
# $$|1\rangle := \begin{bmatrix} 0 \\ 1 \end{bmatrix}.$$

# %% [markdown]
# Pauli gates:
#
# \begin{align}
# \sigma_{j=1} := X &:=
# \begin{pmatrix}
# 0 & 1 \\
# 1 & 0
# \end{pmatrix}. \\
# \sigma_{j=2} := Y &:=
# \begin{pmatrix}
# 0 & -i \\
# i & 0
# \end{pmatrix}. \\
# \sigma_{j=3} := Z &:=
# \begin{pmatrix}
# 1 & 0 \\
# 0 & -1
# \end{pmatrix}.
# \end{align}

# %% [markdown]
# Pauli $X$ Gate acting on the state $|0\rangle$:
#
# \begin{align}
# X |0\rangle &=
# \begin{bmatrix}
# 0 & 1 \\
# 1 & 0
# \end{bmatrix}
# \begin{bmatrix}
# 1 \\ 0
# \end{bmatrix} =
# \begin{bmatrix}
# 0 \\ 1
# \end{bmatrix} = |1\rangle.
# \end{align}

# %% [markdown]
# Pauli $X$ Gate acting on the state $|1\rangle$:
#
# \begin{align}
# X |1\rangle &=
# \begin{bmatrix}
# 0 & 1 \\
# 1 & 0
# \end{bmatrix}
# \begin{bmatrix}
# 0 \\ 1
# \end{bmatrix} =
# \begin{bmatrix}
# 1 \\ 0
# \end{bmatrix} = |0\rangle.
# \end{align}

# %% [markdown]
# # &nbsp; <a href="#"><img valign="middle" height="45px" src="https://img.icons8.com/book" width="45" hspace="0px" vspace="0px"></a> References<a name="ref" />
