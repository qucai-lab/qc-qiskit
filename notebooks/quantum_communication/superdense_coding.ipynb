# %% [markdown]
# <div align="center">
#   <h1><b> Quantum Communication and Cryptography </b></h1>
#   <h2> Superdense Coding </h2>
# </div>
#
# <br>
# <b>Author:</b> <a target="_blank" href="https://github.com/camponogaraviera"> Lucas Camponogara Viera</a>

# %% [markdown]
# # Table of Contents
#
# - [Theory](#theory)
# - [Implementation](#implementation)
# - [References](#references)

# %% [markdown]
# # Theory

# %% [markdown]
# ![superdense.png](attachment:5392cc69-99dd-4ebd-8626-4b9a4bc849a2.png)

# %% [markdown]
# **Goal:** Superdense coding allows Alice to transmit two bits of classical information to Bob by sending only one qubit, using a shared entangled qubit pair as a resource.

# %% [markdown]
# **Steps of the protocol:**
#
# 1. A third party, named Telamon, prepares a pair of qubits $q_1$ and $q_2$ in a maximally entangled Bell state $|\psi^{Bell}\rangle_{AB}$ and then sends qubit $q_1$ to Alice and qubit $q_2$ to Bob.
# 2. To send two classical bits, Alice applies one of four unitary operations {$\mathbb{I}_d, X, Z, XZ$} to her qubit $q_1$.
# 3. Alice then sends her qubit $q_1$ to Bob through a quantum channel.
# 4. Bob performs a Bell-state measurement on both qubits ($q_1$ and $q_2$) to determine which Bell state the pair is in, thereby decoding Alice's two-bit message.

# %% [markdown]
# # Implementation

# %%
import qiskit

# %% [markdown]
# # &nbsp; <a href="#"><img valign="middle" height="45px" src="https://img.icons8.com/book" width="45" hspace="0px" vspace="0px"></a> References<a name="ref" />

# %% [markdown]
# [1] Nielsen MA, Chuang IL. 2010. Quantum Computation and Quantum Information. New York: [Cambridge Univ. Press.](https://doi.org/10.1017/CBO9780511976667) 10th Anniv. Ed.
#
# [2] https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/entanglement-in-action/superdense-coding
