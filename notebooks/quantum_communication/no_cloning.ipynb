# %% [markdown]
# <div align="center">
#   <h1><b> Quantum Communication and Cryptography </b></h1>
#   <h2> No-cloning Theorem </h2>
# </div>
#
# <br>
# <b>Author:</b> <a target="_blank" href="https://github.com/camponogaraviera"> Lucas Camponogara Viera</a>

# %% [markdown]
# # Table of Contents
#
# - [Theorem](#theory)
# - [References](#references)

# %% [markdown]
# # Theorem

# %% [markdown]
# The `no-cloning theorem` states that:
#
# _There is no physical operation that can perfectly copy an arbitrary unknown quantum state._
#
# Obs: Known or orthogonal states can be copied, but not an arbitrary unknown state.

# %% [markdown]
# # &nbsp; <a href="#"><img valign="middle" height="45px" src="https://img.icons8.com/book" width="45" hspace="0px" vspace="0px"></a> References<a name="ref" />

# %% [markdown]
# [1] Nielsen MA, Chuang IL. 2010. Quantum Computation and Quantum Information. New York: [Cambridge Univ. Press.](https://doi.org/10.1017/CBO9780511976667) 10th Anniv. Ed.
#
# [2] https://en.wikipedia.org/wiki/No-cloning_theorem
